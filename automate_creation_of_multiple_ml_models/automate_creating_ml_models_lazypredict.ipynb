# %% [markdown]
# # LazyPredict

# %%
# Please note that this code is executed on Google Colab
# feel free to rerun on either google colab or on your local machine

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install lazypredict

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from IPython.core.display import display
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor,ExtraTreesRegressor

from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, r2_score
from sklearn.model_selection import train_test_split

# import lazypredict

from lazypredict.Supervised import LazyClassifier, LazyRegressor

# %% [markdown]
# ## Classification Problem : LazyClassifier

# %%
stroke_data = pd.read_csv('/content/healthcare-dataset-stroke-data.csv')
stroke_data = stroke_data.drop('id', axis =1)
stroke_data.columns = stroke_data.columns.str.upper() # convert the columns to uppercase

stroke_data
# Out:
#       GENDER   AGE  HYPERTENSION  HEART_DISEASE EVER_MARRIED      WORK_TYPE  \
# 0       Male 67.00             0              1          Yes        Private
# 1     Female 61.00             0              0          Yes  Self-employed
# 2       Male 80.00             0              1          Yes        Private
# 3     Female 49.00             0              0          Yes        Private
# 4     Female 79.00             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female 80.00             1              0          Yes        Private
# 5106  Female 81.00             0              0          Yes  Self-employed
# 5107  Female 35.00             0              0          Yes  Self-employed
# 5108    Male 51.00             0              0          Yes        Private
# 5109  Female 44.00             0              0          Yes       Govt_job
#
# ...

# %%
x_data = stroke_data.drop('STROKE', axis=1)
y_data = stroke_data['STROKE']

X_train, X_test, y_train, y_test = train_test_split(x_data, y_data,test_size=.2,random_state =123)
# y_data

# %%
classifier_model = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None, predictions=True, classifiers='all' )
models,predictions = classifier_model.fit(X_train, X_test, y_train, y_test)

models
# Out:
# 100%|██████████| 29/29 [00:06<00:00,  4.67it/s]
# [LightGBM] [Info] Number of positive: 199, number of negative: 3889
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000522 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 645
# [LightGBM] [Info] Number of data points in the train set: 4088, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.048679 -> initscore=-2.972603
# [LightGBM] [Info] Start training from score -2.972603
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.77               0.74     0.74      0.83
# GaussianNB                         0.27               0.62     0.62      0.36
# BernoulliNB                        0.93               0.59     0.59      0.93
# ...

# %% [markdown]
# ## Regression Problem : LazyRegressor

# %%
housing_data = pd.read_csv('/content/Housing.csv')
housing_data.columns = housing_data.columns.str.upper() # convert the columns to uppercase

housing_data
# Out:
#         PRICE  AREA  BEDROOMS  BATHROOMS  STORIES MAINROAD GUESTROOM BASEMENT  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
# dropping the target from input features
x_data = housing_data.drop('PRICE', axis=1)
# assigning the target
y_data = housing_data['PRICE']

X_train, X_test, y_train, y_test = train_test_split(x_data, y_data,test_size=.2,random_state =123)

# %%
# define the model and run
lzy_regressor = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None, predictions=False, regressors ='all' )
regressor_model ,predictions = lzy_regressor.fit(X_train, X_test, y_train, y_test)

# model_dictionary = classifier_model.provide_models(X_train,X_test,y_train,y_test)
regressor_model
# Out:
# 100%|██████████| 42/42 [00:10<00:00,  4.17it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000109 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 155
# [LightGBM] [Info] Number of data points in the train set: 436, number of used features: 18
# [LightGBM] [Info] Start training from score 4739320.298165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
predictions
# Out:
#                                Adjusted R-Squared  R-Squared         RMSE  \
# Model
# RidgeCV                                      0.58       0.63   1103054.77
# Ridge                                        0.58       0.63   1104453.78
# TransformedTargetRegressor                   0.58       0.63   1104591.76
# LinearRegression                             0.58       0.63   1104591.76
# Lasso                                        0.58       0.63   1104592.43
# PoissonRegressor                             0.58       0.63   1104996.69
# KernelRidge                                  0.58       0.63   1105161.11
# LassoCV                                      0.58       0.63   1105651.84
# ElasticNet                                   0.57       0.62   1118742.62
# SGDRegressor                                 0.57       0.62   1120451.80
# HuberRegressor                               0.56       0.61   1131381.71
# LassoLars                                    0.55       0.60   1145035.25
# ...
